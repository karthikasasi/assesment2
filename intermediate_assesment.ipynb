# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/diabetes_model.csv')
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              5       77             82             41       42  35.8
# 1              9      122             56              0        0  33.3
# 2              0      113             76              0        0  33.3
# 3              1      139             62             41      480  40.7
# 4             10      161             68             23      132  25.5
# ..           ...      ...            ...            ...      ...   ...
# 609            4      114             64              0        0  28.9
# 610            2      175             88              0        0  22.9
# 611            3      121             52              0        0  36.0
# 612            7      136             74             26      135  26.0
# 613            4      156             75              0        0  48.3
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.156   35        0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               614 non-null    int64
#  1   Glucose                   614 non-null    int64
#  2   BloodPressure             614 non-null    int64
#  3   SkinThickness             614 non-null    int64
#  4   Insulin                   614 non-null    int64
#  5   BMI                       614 non-null    float64
#  6   DiabetesPedigreeFunction  614 non-null    float64
#  7   Age                       614 non-null    int64
#  8   Outcome                   614 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 43.3 KB

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   614.000000  614.000000     614.000000     614.000000  614.000000
# mean      3.845277  121.500000      69.599349      20.400651   79.035831
# std       3.403362   32.275918      18.924485      16.113962  117.108037
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.500000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      22.500000   24.000000
# 75%       6.000000  141.000000      80.000000      33.000000  127.500000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  614.000000                614.000000  614.000000  614.000000
# mean    32.210423                  0.476373   33.289902    0.350163
# std      7.965291                  0.343502   11.837425    0.477410
# ...

# %%
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
df.nunique()
# Out:
# Pregnancies                  17
# Glucose                     131
# BloodPressure                47
# SkinThickness                50
# Insulin                     159
# BMI                         232
# DiabetesPedigreeFunction    446
# Age                          52
# Outcome                       2
# dtype: int64

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
df['BMI'].mean()
# Out:
# 32.21042345276873

# %%
df['BMI'].median()
# Out:
# 32.150000000000006

# %%
df['BMI'].std()
# Out:
# 7.9652910687938645

# %%
df.plot(x='Age', y='BMI', kind='scatter')
# Out:
# <Axes: xlabel='Age', ylabel='BMI'>

# %%
df.plot(x='Age', y='BMI', kind='bar')
# Out:
# <Axes: xlabel='Age'>

# %%
df['Age'].quantile(0.25)
# Out:
# 24.0

# %%
df['Age'].quantile(0.75)
# Out:
# 41.0

# %%
df.plot(x='Age', y='BMI', kind='box')
# Out:
# <Axes: >

# %%
df.plot(x='Age', y='BMI', kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df2 = pd.read_csv('/content/ny-flights.csv')
df2
# Out:
#                    fl_date unique_carrier  airline_id tail_num  fl_num origin  \
# 0      2014-01-01 00:00:00             AA       19805   N338AA       1    JFK
# 1      2014-01-01 00:00:00             AA       19805   N335AA       3    JFK
# 2      2014-01-01 00:00:00             AA       19805   N327AA      21    JFK
# 3      2014-01-01 00:00:00             AA       19805   N3EHAA      29    LGA
# 4      2014-01-01 00:00:00             AA       19805   N319AA     117    JFK
# ...                    ...            ...         ...      ...     ...    ...
# 20812  2014-01-31 00:00:00             UA       19977   N54711    1253    ROC
# 20813  2014-01-31 00:00:00             UA       19977   N77525    1429    LGA
# 20814  2014-01-31 00:00:00             UA       19977   N37293    1456    LGA
# 20815  2014-01-31 00:00:00             UA       19977   N24729    1457    LGA
# 20816  2014-01-31 00:00:00             MQ       20398   N609MQ    3699    BUF
#
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20817 entries, 0 to 20816
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   fl_date         20817 non-null  object
#  1   unique_carrier  20817 non-null  object
#  2   airline_id      20817 non-null  int64
#  3   tail_num        20512 non-null  object
#  4   fl_num          20817 non-null  int64
#  5   origin          20817 non-null  object
#  6   dest            20817 non-null  object
#  7   dep_time        18462 non-null  float64
#  8   dep_delay       18462 non-null  float64
#  9   arr_time        18412 non-null  float64
#  10  arr_delay       18383 non-null  float64
#  11  cancelled       20817 non-null  float64
#  12  arr             18412 non-null  object
#  13  dep             18462 non-null  object
# dtypes: float64(5), int64(2), object(7)
# memory usage: 2.2+ MB

# %%
df2.describe()
# Out:
#          airline_id        fl_num      dep_time     dep_delay      arr_time  \
# count  20817.000000  20817.000000  18462.000000  18462.000000  18412.000000
# mean   20109.614882   1826.098813   1319.991713     22.772127   1493.698566
# std      370.715209   1548.188325    479.999940     59.766152    518.851657
# min    19393.000000      1.000000      1.000000   -112.000000      1.000000
# 25%    19790.000000    472.000000    858.000000     -4.000000   1110.750000
# 50%    20355.000000   1457.000000   1336.000000      0.000000   1519.000000
# 75%    20409.000000   2701.000000   1720.000000     22.000000   1923.000000
# max    21171.000000   6258.000000   2400.000000    973.000000   2400.000000
#
#           arr_delay    cancelled
# count  18383.000000  20817.00000
# mean      21.380732      0.11505
# std       64.605591      0.31909
# min     -112.000000      0.00000
# 25%      -12.000000      0.00000
# 50%        3.000000      0.00000
# 75%       28.000000      0.00000
# ...

# %%
df2.isnull().sum()
# Out:
# fl_date              0
# unique_carrier       0
# airline_id           0
# tail_num           305
# fl_num               0
# origin               0
# dest                 0
# dep_time          2355
# dep_delay         2355
# arr_time          2405
# arr_delay         2434
# cancelled            0
# arr               2405
# dep               2355
# dtype: int64

# %%
df2.nunique()
# Out:
# fl_date              31
# unique_carrier       13
# airline_id           13
# tail_num           2734
# fl_num             1202
# origin               11
# dest                 83
# dep_time           1170
# dep_delay           439
# arr_time           1280
# arr_delay           488
# cancelled             2
# arr               13914
# dep               13532
# dtype: int64

# %%
df2.columns
# Out:
# Index(['fl_date', 'unique_carrier', 'airline_id', 'tail_num', 'fl_num',
#        'origin', 'dest', 'dep_time', 'dep_delay', 'arr_time', 'arr_delay',
#        'cancelled', 'arr', 'dep'],
#       dtype='object')

# %%
df2['airline_id'].mean()
# Out:
# 20109.61488206754

# %%
df2['airline_id'].median()
# Out:
# 20355.0

# %%
df2['airline_id'].std()
# Out:
# 370.715208910921

# %%
df2.plot(x='airline_id', y='arr_delay', kind='scatter')
# Out:
# <Axes: xlabel='airline_id', ylabel='arr_delay'>

# %%
df2['airline_id'].quantile(0.25)
# Out:
# 19790.0

# %%
df2['airline_id'].quantile(0.75)
# Out:
# 20409.0

# %%
df2.plot(x='airline_id', y='arr_delay', kind='box')
# Out:
# <Axes: >

# %%
df2.plot(x='airline_id', y='arr_delay', kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df2['arr_delay'].corr(df2['airline_id'])
# Out:
# 0.01863718619933225

# %%
combined_df = pd.concat([df, df2], ignore_index=True)
combined_df
# Out:
#        Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              5.0     77.0           82.0           41.0     42.0  35.8
# 1              9.0    122.0           56.0            0.0      0.0  33.3
# 2              0.0    113.0           76.0            0.0      0.0  33.3
# 3              1.0    139.0           62.0           41.0    480.0  40.7
# 4             10.0    161.0           68.0           23.0    132.0  25.5
# ...            ...      ...            ...            ...      ...   ...
# 21426          NaN      NaN            NaN            NaN      NaN   NaN
# 21427          NaN      NaN            NaN            NaN      NaN   NaN
# 21428          NaN      NaN            NaN            NaN      NaN   NaN
# 21429          NaN      NaN            NaN            NaN      NaN   NaN
# 21430          NaN      NaN            NaN            NaN      NaN   NaN
#
#        DiabetesPedigreeFunction   Age  Outcome              fl_date  ...  \
# ...

# %%
combined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21431 entries, 0 to 21430
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               614 non-null    float64
#  1   Glucose                   614 non-null    float64
#  2   BloodPressure             614 non-null    float64
#  3   SkinThickness             614 non-null    float64
#  4   Insulin                   614 non-null    float64
#  5   BMI                       614 non-null    float64
#  6   DiabetesPedigreeFunction  614 non-null    float64
#  7   Age                       614 non-null    float64
#  8   Outcome                   614 non-null    float64
#  9   fl_date                   20817 non-null  object
#  10  unique_carrier            20817 non-null  object
#  11  airline_id                20817 non-null  float64
#  12  tail_num                  20512 non-null  object
# ...

# %%
combined_df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   614.000000  614.000000     614.000000     614.000000  614.000000
# mean      3.845277  121.500000      69.599349      20.400651   79.035831
# std       3.403362   32.275918      18.924485      16.113962  117.108037
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.500000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      22.500000   24.000000
# 75%       6.000000  141.000000      80.000000      33.000000  127.500000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome  \
# count  614.000000                614.000000  614.000000  614.000000
# mean    32.210423                  0.476373   33.289902    0.350163
# std      7.965291                  0.343502   11.837425    0.477410
# ...

# %%
combined_df.isnull().sum()
# Out:
# Pregnancies                 20817
# Glucose                     20817
# BloodPressure               20817
# SkinThickness               20817
# Insulin                     20817
# BMI                         20817
# DiabetesPedigreeFunction    20817
# Age                         20817
# Outcome                     20817
# fl_date                       614
# unique_carrier                614
# airline_id                    614
# tail_num                      919
# fl_num                        614
# origin                        614
# dest                          614
# dep_time                     2969
# dep_delay                    2969
# arr_time                     3019
# arr_delay                    3048
# cancelled                     614
# arr                          3019
# dep                          2969
# dtype: int64

# %%
combined_df.nunique()
# Out:
# Pregnancies                    17
# Glucose                       131
# BloodPressure                  47
# SkinThickness                  50
# Insulin                       159
# BMI                           232
# DiabetesPedigreeFunction      446
# Age                            52
# Outcome                         2
# fl_date                        31
# unique_carrier                 13
# airline_id                     13
# tail_num                     2734
# fl_num                       1202
# origin                         11
# dest                           83
# dep_time                     1170
# dep_delay                     439
# arr_time                     1280
# arr_delay                     488
# cancelled                       2
# arr                         13914
# dep                         13532
# dtype: int64

# %%
combined_df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome', 'fl_date',
#        'unique_carrier', 'airline_id', 'tail_num', 'fl_num', 'origin', 'dest',
#        'dep_time', 'dep_delay', 'arr_time', 'arr_delay', 'cancelled', 'arr',
#        'dep'],
#       dtype='object')

# %%
combined_df.dtypes
# Out:
# Pregnancies                 float64
# Glucose                     float64
# BloodPressure               float64
# SkinThickness               float64
# Insulin                     float64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                         float64
# Outcome                     float64
# fl_date                      object
# unique_carrier               object
# airline_id                  float64
# tail_num                     object
# fl_num                      float64
# origin                       object
# dest                         object
# dep_time                    float64
# dep_delay                   float64
# arr_time                    float64
# arr_delay                   float64
# cancelled                   float64
# arr                          object
# dep                          object
# dtype: object

# %%
combined_df.shape
# Out:
# (21431, 23)

# %%
combined_df['Age'].value_counts()
# Out:
# Age
# 22.0    57
# 21.0    50
# 25.0    42
# 24.0    36
# 23.0    31
# 26.0    28
# 28.0    26
# 27.0    25
# 29.0    23
# 31.0    20
# 41.0    18
# 30.0    17
# 33.0    15
# 37.0    14
# 43.0    13
# 45.0    13
# 46.0    13
# 42.0    13
# 34.0    11
# 32.0    11
# 40.0    10
# 38.0    10
# 39.0     9
# 35.0     9
# 36.0     8
# 52.0     8
# 44.0     7
# 51.0     6
# 47.0     6
# 58.0     6
# 50.0     5
# 48.0     5
# 53.0     5
# 66.0     4
# 49.0     4
# 60.0     4
# 63.0     3
# 54.0     3
# 62.0     3
# 57.0     3
# 59.0     3
# 56.0     3
# 55.0     3
# 65.0     2
# 67.0     2
# 61.0     1
# 70.0     1
# 68.0     1
# 69.0     1
# 64.0     1
# 81.0     1
# 72.0     1
# Name: count, dtype: int64

# %%
combined_df['Age'].mean()
# Out:
# 33.28990228013029

# %%
combined_df['Age'].median()
# Out:
# 29.0

# %%
combined_df['Age'].std()
# Out:
# 11.837424918523935

# %%
combined_df['Age'].corr(combined_df['BMI'])
# Out:
# 0.037499773828295

# %%
combined_df.plot(x='Age', y='BMI', kind='scatter')
# Out:
# <Axes: xlabel='Age', ylabel='BMI'>

# %%
combined_df.plot(x='Age', y='BMI', kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
combined_df.plot(x='Age', y='BMI', kind='box')
# Out:
# <Axes: >

# %%
combined_df.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>
